# %%
import cli

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sodapy import Socrata

# %%
client = Socrata("data.cityofchicago.org", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
metadata = client.get_metadata('22u3-xenr')

# %%
metadata.keys()
# Out:
# dict_keys(['id', 'name', 'attribution', 'attributionLink', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'indexUpdatedAt', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowIdentifierColumnId', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'approvals', 'columns', 'grants', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
metadata['columns']
# Out:
# [{'id': 339325551,
#   'name': 'ID',
#   'dataTypeName': 'text',
#   'fieldName': 'id',
#   'position': 1,
#   'renderTypeName': 'text',
#   'tableColumnId': 3282044,
#   'width': 95,
#   'cachedContents': {'largest': '999665',
#    'non_null': 1613654,
#    'null': '0',
#    'top': [{'item': '1001847', 'count': '1'},
#     {'item': '1002009', 'count': '1'},
#     {'item': '1002038', 'count': '1'},
#     {'item': '1002039', 'count': '1'},
#     {'item': '1002040', 'count': '1'},
#     {'item': '1002042', 'count': '1'},
#     {'item': '1002044', 'count': '1'},
#     {'item': '1002047', 'count': '1'},
#     {'item': '1002048', 'count': '1'},
#     {'item': '1003969', 'count': '1'},
#     {'item': '1003970', 'count': '1'},
#     {'item': '1007960', 'count': '1'},
#     {'item': '1007961', 'count': '1'},
#     {'item': '1007963', 'count': '1'},
#     {'item': '1007964', 'count': '1'},
#     {'item': '1007967', 'count': '1'},
#     {'item': '1011895', 'count': '1'},
# ...

# %%
cli.get_row_count(client, '22u3-xenr')
# Out:
# 1640602

# %%
api_data = client.get(
    '22u3-xenr',
    limit=5000)

# %%
api_data
# Out:
# [{'id': '6298894',
#   'violation_last_modified_date': '2019-07-15T06:28:54.000',
#   'violation_date': '2019-07-15T00:00:00.000',
#   'violation_code': 'CN104015',
#   'violation_status': 'OPEN',
#   'violation_description': 'REPLCE WINDOW PANES, PLEXGLAS',
#   'violation_location': 'OTHER   :    :OTHER',
#   'violation_inspector_comments': 'APARTMENT 308 AND 206, WINDOW PANES; BOARDED UP.',
#   'violation_ordinance': 'Replace broken, missing or defective window panes. (13-196-550 A)',
#   'inspector_id': 'BL00444',
#   'inspection_number': '12241124',
#   'inspection_status': 'FAILED',
#   'inspection_waived': 'N',
#   'inspection_category': 'PERIODIC',
#   'department_bureau': 'CONSERVATION',
#   'address': '952 E 79TH ST',
#   'street_number': '952',
#   'street_direction': 'E',
#   'street_name': '79TH',
#   'street_type': 'ST',
#   'property_group': '418292',
#   'ssa': '51',
#   'latitude': '41.75144495',
#   'longitude': '-87.600651542',
# ...

# %%
api_data[0]
# Out:
# {'id': '6298894',
#  'violation_last_modified_date': '2019-07-15T06:28:54.000',
#  'violation_date': '2019-07-15T00:00:00.000',
#  'violation_code': 'CN104015',
#  'violation_status': 'OPEN',
#  'violation_description': 'REPLCE WINDOW PANES, PLEXGLAS',
#  'violation_location': 'OTHER   :    :OTHER',
#  'violation_inspector_comments': 'APARTMENT 308 AND 206, WINDOW PANES; BOARDED UP.',
#  'violation_ordinance': 'Replace broken, missing or defective window panes. (13-196-550 A)',
#  'inspector_id': 'BL00444',
#  'inspection_number': '12241124',
#  'inspection_status': 'FAILED',
#  'inspection_waived': 'N',
#  'inspection_category': 'PERIODIC',
#  'department_bureau': 'CONSERVATION',
#  'address': '952 E 79TH ST',
#  'street_number': '952',
#  'street_direction': 'E',
#  'street_name': '79TH',
#  'street_type': 'ST',
#  'property_group': '418292',
#  'ssa': '51',
#  'latitude': '41.75144495',
#  'longitude': '-87.600651542',
#  'location': {'latitude': '41.75144495023618',
# ...
